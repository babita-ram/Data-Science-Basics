# %% [markdown]
# # Common Python Data Analytics Libraries

# %% [markdown]
# ### Pandas: Helps create data frame
# data structure and an analysis tool for python programming language. Pandas provide us a data frame to store the data in a clear and concise way.

# %%
import pandas as pd

# %% [markdown]
# ### Numpy: Helps create 2D arrays

# %%
import numpy  as np

# %% [markdown]
# ### Matplotlib.pyplot: Visualization Tool
# Matplotlib is a 2D plotting python library, with which we can plot various plots in python across various environments. It is an alternate to seaborn, and seaborn is based on matplotlib.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Seaborn : Alternate to MatPlotLib, Visulization Library

# %%
import seaborn as sns

# %% [markdown]
# ### Scikit learn : Data Science Library
#
# It is an easy-to-use Python library that is used to build a machine learning model. It is built on NumPy, SciPy, and matplotlib. Below is the official documentation for the scikit learn library.
# ![image.png](attachment:image.png)

# %%
import sklearn
